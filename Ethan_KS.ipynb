# %%
import numpy as np
import pandas as pd
import scipy.stats as stats

import seaborn as sns
import matplotlib.pyplot as plt

import statsmodels
import statsmodels.api as sm
import statsmodels.formula.api as smf

df = pd.read_csv('Leena_df1Clean.csv')

# %%
df['Admission grade'].value_counts()
# Out:
# Admission grade
# 130.0    162
# 140.0    153
# 120.0    145
# 100.0    116
# 150.0     81
#         ...
# 150.6      1
# 184.4      1
# 102.6      1
# 147.3      1
# 156.2      1
# Name: count, Length: 620, dtype: int64

# %% [markdown]
# # Kolmogorov-Smirnov Test

# %%
df.hist(column='Admission grade')
# Out:
# array([[<Axes: title={'center': 'Admission grade'}>]], dtype=object)

# %%
adGrade = df['Admission grade']
xrange = np.linspace(adGrade.min(), adGrade.max(), len(adGrade))

# %%
F0 = stats.norm(0, 2).cdf(xrange)

FX = np.array([sum(adGrade < x) for x in xrange]) / len(adGrade)

fig, ax = plt.subplots(1, 1, figsize=(5, 5))
ax.plot(xrange, F0, label='Null CDF')
ax.plot(xrange, FX, label='EDF')
ax.legend()

# %%
plt.hist(xrange, bins=len(adGrade))
# Out:
# (array([1., 1., 1., ..., 1., 1., 1.]),
#  array([ 95.        ,  95.02147378,  95.04294756, ..., 189.95705244,
#         189.97852622, 190.        ]),
#  <BarContainer object of 4424 artists>)
