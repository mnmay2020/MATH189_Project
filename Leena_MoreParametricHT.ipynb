# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt 
import seaborn as sns 

import statsmodels
import statsmodels.api as sm
import scipy.stats as stats

# %% [markdown]
# ##### Loading data - adopted from Leena_EDA

# %%
df1 = pd.read_csv('Leena_df1Clean.csv')
df1.head()
# Out:
#   Marital Status                               Course Previous qualification  \
# 0         Single      Animation and Multimedia Design              Secondary
# 1         Single                              Tourism              Secondary
# 2         Single                 Communication Design              Secondary
# 3         Single         Journalism and Communication              Secondary
# 4        Married  Social Service (evening attendance)              Secondary
#
#    Previous qualification (grade) Mother's qualification  \
# 0                           122.0                  Basic
# 1                           160.0              Secondary
# 2                           122.0                  Basic
# 3                           122.0                  Basic
# 4                           100.0                  Basic
#
#   Father's qualification  Mother's occupation  Father's occupation  \
# 0                  Basic                    5                    9
# ...

# %%
df1_grad = df1[df1.get('Target') == 'Graduate/Enrolled']
df1_drop = df1[df1.get('Target') == 'Dropout']

# %% [markdown]
# ## Test of Homogeneity

# %% [markdown]
# ### Mother's and Father's qualification
#
# > Is there a difference in the distribution of the each students' parent's qualification between those who dropped out and those who graduated/are enrolled?

# %% [markdown]
# #### Mother's Qualification

# %%
pivot_table = pd.crosstab(df1['Target'], df1['Mother\'s qualification'])
pivot_table
# Out:
# Mother's qualification  Basic  Higher  Secondary  Unknown
# Target
# Dropout                   834     191        300       96
# Graduate/Enrolled        1763     437        769       34

# %%
sqtab = sm.stats.SquareTable(pivot_table)
print(sqtab.homogeneity())
# Out:
# df          5
# pvalue      0.0
# statistic   4412.042205636382
