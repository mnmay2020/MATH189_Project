# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt 
import seaborn as sns 

import statsmodels

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
predict_students_dropout_and_academic_success = fetch_ucirepo(id=697) 
  
# data (as pandas dataframes) 
X = predict_students_dropout_and_academic_success.data.features 
y = predict_students_dropout_and_academic_success.data.targets 

df1_raw = X.assign(Target=y.get('Target'))
df1_raw.head()
# Out:
#    Marital Status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
df1_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital Status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4424 non-null   int64
# ...

# %%
dropout_df = df1_raw[df1_raw['Target'] == 'Dropout']
num_dropouts = dropout_df.groupby('Scholarship holder').size()


plt.figure(figsize=(9,5))
num_dropouts.plot(kind='bar')
plt.title('Number of Dropouts by Scholarship holder')
plt.xlabel('Scholarship Holder')
plt.ylabel('Number of Dropouts')
plt.show()

# %%
dropout_df = df1_raw[df1_raw['Target'] == 'Dropout']
num_dropouts = dropout_df.groupby('Debtor').size()


plt.figure(figsize=(9,5))
num_dropouts.plot(kind='bar')
plt.title('Number of Dropouts Based on Debt')
plt.xlabel('Debtor')
plt.ylabel('Number of Dropouts')
plt.show()

# %% [markdown]
# Debt is not really a factor^^

# %%
dropout_df = df1_raw[df1_raw['Target'] == 'Dropout']
num_dropouts = dropout_df.groupby('Educational special needs').size()


plt.figure(figsize=(9,5))
num_dropouts.plot(kind='bar')
plt.title('Number of Dropouts Based on Educational Special Needs')
plt.xlabel('Educational Special Needs')
plt.ylabel('Number of Dropouts')
plt.show()

# %%
dropout_df = df1_raw[df1_raw['Target'] == 'Dropout']
num_dropouts = dropout_df.groupby('Curricular units 1st sem (credited)').size()


plt.figure(figsize=(9,5))
num_dropouts.plot(kind='bar')
plt.title('Number of Dropouts Based on credited units 1st semester')
plt.xlabel('Curricular units 1st sem')
plt.ylabel('Number of Dropouts')
plt.show()

# %%
dropout_df = df1_raw[df1_raw['Target'] == 'Dropout']
num_dropouts = dropout_df.groupby('Curricular units 2nd sem (credited)').size()


plt.figure(figsize=(9,5))
num_dropouts.plot(kind='bar')
plt.title('Number of Dropouts Based on credited units 2nd semester')
plt.xlabel('Curricular units 1st sem')
plt.ylabel('Number of Dropouts')
plt.show()

# %%
dropout_df = df1_raw[df1_raw['Target'] == 'Dropout']
num_dropouts = dropout_df.groupby('Curricular units 2nd sem (enrolled)').size()


plt.figure(figsize=(9,5))
num_dropouts.plot(kind='bar')
plt.title('Number of Dropouts Based on enrolled units 2nd semester')
plt.xlabel('Curricular units 2nd sem (enrolled)')
plt.ylabel('Number of Dropouts')
plt.show()

# %%
dropout_df = df1_raw[df1_raw['Target'] == 'Dropout']
num_dropouts = dropout_df.groupby('Curricular units 2nd sem (grade)').size()


plt.figure(figsize=(9,5))
num_dropouts.plot(kind='bar')
plt.title('Number of Dropouts Based on grades 2nd semester')
plt.xlabel('Curricular units 2nd sem (grade)')
plt.ylabel('Number of Dropouts')
plt.show()
